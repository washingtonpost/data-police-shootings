# %%
import pandas as pd

# %%
# Functions
class CleanData:
    def __init__(self, df):
        self.df = df
        
    def get_record(self, name: str):
        return self.df[self.df.name == name]

    def keep_record(self, records: list):
        for record in records:
            self.df.loc[record, 'keep'] = True

# %%
# Import data
df = pd.read_csv("fatal-police-shootings-data.csv", index_col="id")

# Add a column to determine if we want to keep the data or not
df["keep"] = True
df.head()
# Out:
#                   name        date   manner_of_death       armed   age gender  \
# id
# 3           Tim Elliot  2015-01-02              shot         gun  53.0      M
# 4     Lewis Lee Lembke  2015-01-02              shot         gun  47.0      M
# 5   John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0      M
# 8      Matthew Hoffman  2015-01-04              shot  toy weapon  32.0      M
# 9    Michael Rodriguez  2015-01-04              shot    nail gun  39.0      M
#
#    race           city state  signs_of_mental_illness threat_level  \
# id
# 3     A        Shelton    WA                     True       attack
# 4     W          Aloha    OR                    False       attack
# 5     H        Wichita    KS                    False        other
# 8     W  San Francisco    CA                     True       attack
# 9     H          Evans    CO                    False       attack
#
#            flee  body_camera  keep
# id
# 3   Not fleeing        False  True
# 4   Not fleeing        False  True
# 5   Not fleeing        False  True
# 8   Not fleeing        False  True
# 9   Not fleeing        False  True

# %%
len(df)
# Out:
# 5424

# %% [markdown]
# # Checking Duplicates

# %%
# Remove TK TK (TK = to come, https://en.wikipedia.org/wiki/To_come_(publishing))
df_notk = df[df.name != "TK TK"].copy()

# Check for duplicate records in which name and state are the same
duplicated = list(df_notk[df_notk.duplicated(["name", "state"], keep="first")].name)

# %%
# Set all duplicate values to keep = False
df.loc[df.name.isin(duplicated), "keep"] = False

# Instantiate CleanData class
clean = CleanData(df)

# Filter the original dataset to look at the duplicated values
duplicated_df = df[df.name.isin(duplicated)].copy()
duplicated_df
# Out:
#                           name        date manner_of_death         armed  \
# id
# 614           Daniel Hernandez  2015-07-07            shot           gun
# 4195         Roderick McDaniel  2018-11-19            shot           gun
# 4237         Roderick McDaniel  2018-11-20            shot       vehicle
# 5128           Clayton Andrews  2019-10-25            shot           gun
# 5135           Clayton Andrews  2019-10-26            shot           gun
# 5150             Benjamin Diaz  2019-11-01            shot  sharp object
# 5191             Benjamin Diaz  2019-11-01            shot    box cutter
# 5389     Miguel Mercado Segura  2020-01-20            shot           gun
# 5515     Miguel Mercado Segura  2020-01-21            shot           gun
# 5537  Timothy Leroy Harrington  2020-02-14            shot           gun
# 5548  Timothy Leroy Harrington  2020-02-14            shot           gun
# 5572               Terry Hasty  2020-02-25            shot           gun
# 5603               Terry Hasty  2020-02-25            shot           gun
# 5691     William Patrick Floyd  2020-03-27            shot           gun
# 5721     William Patrick Floyd  2020-03-27            shot           gun
# 5782          Daniel Hernandez  2020-04-30            shot           gun
#
#        age gender race             city state  signs_of_mental_illness  \
# id
# 614   47.0      M    H      Bakersfield    CA                    False
# 4195  33.0      M    B         Magnolia    AR                    False
# 4237  33.0      M    B         Magnolia    AR                    False
# 5128  40.0      M    W           Kansas    OK                    False
# 5135  40.0      M    W     Creek County    OK                     True
# 5150  22.0      M    H       Alamogordo    NM                    False
# 5191  22.0      M    H       Alamogordo    NM                    False
# 5389  31.0      M    H  Fountain Valley    CA                    False
# 5515  31.0      M    H  Fountain Valley    CA                    False
# 5537  58.0      M    W          Polkton    NC                    False
# 5548  58.0      M    W          Polkton    NC                    False
# 5572  56.0      M  NaN    Sumter County    SC                    False
# 5603  56.0      M  NaN          Dalzell    SC                    False
# 5691  51.0      M  NaN         Portland    OR                    False
# 5721  51.0      M  NaN            Salem    OR                    False
# 5782   NaN      M  NaN      Los Angeles    CA                    False
#
#      threat_level         flee  body_camera   keep
# id
# 614        attack  Not fleeing        False  False
# 4195       attack  Not fleeing        False  False
# 4237       attack  Not fleeing        False  False
# 5128       attack  Not fleeing        False  False
# 5135       attack          Car        False  False
# 5150       attack          Car        False  False
# 5191       attack  Not fleeing        False  False
# 5389        other         Foot        False  False
# 5515        other         Foot        False  False
# 5537        other          Car        False  False
# 5548       attack          Car        False  False
# 5572       attack  Not fleeing        False  False
# 5603       attack  Not fleeing        False  False
# 5691        other  Not fleeing        False  False
# 5721        other          NaN        False  False
# 5782        other          Car        False  False

# %%
# Number of duplicate values
len(duplicated_df.name.unique())
# Out:
# 8

# %%
name = "Terry Hasty"
# 5572 [ref](https://www.wmbfnews.com/2020/02/25/deputy-suspect-shot-sumter-county-residence/)
clean.keep_record([5572])
clean.get_record(name)
# Out:
#              name        date manner_of_death armed   age gender race  \
# id
# 5572  Terry Hasty  2020-02-25            shot   gun  56.0      M  NaN
# 5603  Terry Hasty  2020-02-25            shot   gun  56.0      M  NaN
#
#                city state  signs_of_mental_illness threat_level         flee  \
# id
# 5572  Sumter County    SC                    False       attack  Not fleeing
# 5603        Dalzell    SC                    False       attack  Not fleeing
#
#       body_camera   keep
# id
# 5572        False   True
# 5603        False  False

# %%
name = "Daniel Hernandez"
# Keep both entries, different dates
# 614 [ref](https://www.bakersfield.com/archives/bakersfield-police-man-fatally-shot-tuesday-pointed-gun-at-officers/article_1fc51179-1fbe-5e1b-8938-a122e0080cb3.html)
# 5782 [ref](https://www.latimes.com/california/story/2020-05-07/lapd-officers-named-in-fatal-shooting-of-alleged-gunman)
clean.keep_record([614, 5782])
clean.get_record(name)
# Out:
#                   name        date manner_of_death armed   age gender race  \
# id
# 614   Daniel Hernandez  2015-07-07            shot   gun  47.0      M    H
# 5782  Daniel Hernandez  2020-04-30            shot   gun   NaN      M  NaN
#
#              city state  signs_of_mental_illness threat_level         flee  \
# id
# 614   Bakersfield    CA                    False       attack  Not fleeing
# 5782  Los Angeles    CA                    False        other          Car
#
#       body_camera  keep
# id
# 614         False  True
# 5782        False  True

# %%
name = "Roderick McDaniel"
# Likely 4237 is the correct entry
# 4237 [ref](https://www.arkansasonline.com/news/2018/nov/28/prosecutor-details-magnolia-slayings-20/)

clean.keep_record([4237])
clean.get_record(name)
# Out:
#                    name        date manner_of_death    armed   age gender  \
# id
# 4195  Roderick McDaniel  2018-11-19            shot      gun  33.0      M
# 4237  Roderick McDaniel  2018-11-20            shot  vehicle  33.0      M
#
#      race      city state  signs_of_mental_illness threat_level         flee  \
# id
# 4195    B  Magnolia    AR                    False       attack  Not fleeing
# 4237    B  Magnolia    AR                    False       attack  Not fleeing
#
#       body_camera   keep
# id
# 4195        False  False
# 4237        False   True

# %%
name = "Clayton Andrews"
# 5128 [ref](https://hl.nwaonline.com/news/2019/oct/30/osbi-investigating-fatal-officer-involv/)

clean.keep_record([5128])
clean.get_record(name)
# Out:
#                  name        date manner_of_death armed   age gender race  \
# id
# 5128  Clayton Andrews  2019-10-25            shot   gun  40.0      M    W
# 5135  Clayton Andrews  2019-10-26            shot   gun  40.0      M    W
#
#               city state  signs_of_mental_illness threat_level         flee  \
# id
# 5128        Kansas    OK                    False       attack  Not fleeing
# 5135  Creek County    OK                     True       attack          Car
#
#       body_camera   keep
# id
# 5128        False   True
# 5135        False  False

# %%
name = "Benjamin Diaz"
# NUM [ref](https://kfoxtv.com/news/local/officer-involved-shooting-reported-near-alamogordo)

clean.keep_record([5191])
clean.get_record(name)
# Out:
#                name        date manner_of_death         armed   age gender  \
# id
# 5150  Benjamin Diaz  2019-11-01            shot  sharp object  22.0      M
# 5191  Benjamin Diaz  2019-11-01            shot    box cutter  22.0      M
#
#      race        city state  signs_of_mental_illness threat_level  \
# id
# 5150    H  Alamogordo    NM                    False       attack
# 5191    H  Alamogordo    NM                    False       attack
#
#              flee  body_camera   keep
# id
# 5150          Car        False  False
# 5191  Not fleeing        False   True

# %%
name = "Miguel Mercado Segura"
# Occured on the Jan 20, 2020
# [ref](https://www.latimes.com/socal/daily-pilot/news/story/2020-01-22/man-killed-in-officer-involved-shooting-in-fountain-valley-is-identified)

clean.keep_record([5515])
clean.get_record(name)
# Out:
#                        name        date manner_of_death armed   age gender  \
# id
# 5389  Miguel Mercado Segura  2020-01-20            shot   gun  31.0      M
# 5515  Miguel Mercado Segura  2020-01-21            shot   gun  31.0      M
#
#      race             city state  signs_of_mental_illness threat_level  flee  \
# id
# 5389    H  Fountain Valley    CA                    False        other  Foot
# 5515    H  Fountain Valley    CA                    False        other  Foot
#
#       body_camera   keep
# id
# 5389        False  False
# 5515        False   True

# %%
name = "Timothy Leroy Harrington"
# Threat level unclear
# 5537 [ref](https://www.wbtv.com/2020/02/15/deputy-fatally-shoots-armed-suspect-anson-co-sheriff-says/)

clean.keep_record([5537])
clean.get_record(name)
# Out:
#                           name        date manner_of_death armed   age gender  \
# id
# 5537  Timothy Leroy Harrington  2020-02-14            shot   gun  58.0      M
# 5548  Timothy Leroy Harrington  2020-02-14            shot   gun  58.0      M
#
#      race     city state  signs_of_mental_illness threat_level flee  \
# id
# 5537    W  Polkton    NC                    False        other  Car
# 5548    W  Polkton    NC                    False       attack  Car
#
#       body_camera   keep
# id
# 5537        False   True
# 5548        False  False

# %%
name = "William Patrick Floyd"
# Occured in Portland
# 5691 [ref](https://www.oregonlive.com/pacific-northwest-news/2020/03/troopers-fatally-shoot-person-on-i-5-south-of-salem.html)

clean.keep_record([5691])
clean.get_record(name)
# Out:
#                        name        date manner_of_death armed   age gender  \
# id
# 5691  William Patrick Floyd  2020-03-27            shot   gun  51.0      M
# 5721  William Patrick Floyd  2020-03-27            shot   gun  51.0      M
#
#      race      city state  signs_of_mental_illness threat_level         flee  \
# id
# 5691  NaN  Portland    OR                    False        other  Not fleeing
# 5721  NaN     Salem    OR                    False        other          NaN
#
#       body_camera   keep
# id
# 5691        False   True
# 5721        False  False

# %%
# Keep only the records we want
df = df[df.keep == True]

# Drop the keep column
df.drop(columns=["keep"], axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-0aad8d1d3da2> in <module>
#       1 # Keep only the records we want
# ----> 2 df = df[df.keep == True].copy()
#       3
#       4 # Drop the keep column
#       5 df.drop(columns=["keep"], axis=0, inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'keep'

# %%
len(df)
# Out:
# 5417

# %%
# Export to csv
df.to_csv("fatal-police-shootings-data.csv", index=False)

# %% [markdown]
# # Reading
#
# #### AN EMPIRICAL ANALYSIS OF RACIAL DIFFERENCES IN POLICE USE OF FORCE
# *Roland G. Fryer, Jr*
#
# https://www.nber.org/papers/w22399.pdf
#
# #### CAN WE PULL BACK FROM THE BRINK
# *Sam Harris*
#
# https://samharris.org/can-pull-back-brink/
